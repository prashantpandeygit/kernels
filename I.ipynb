# %% [markdown]
# #### **Triton**

# %% [markdown]
# #### **Warp Scheduler**
# **Threads are independent, but are not scheduled independently, warp groups them and performs operations, each warp can have upto 32 threads**

# %% [markdown]
# #### **Memory Coalescing**
# **Better to store data sequentially in such a way that fetching it is also easy and sequential, eg: store as row major or column major as per data is fetched by the view**
